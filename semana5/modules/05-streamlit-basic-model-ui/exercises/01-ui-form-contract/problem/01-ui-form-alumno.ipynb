# %% [markdown]
# # Práctica — contrato de formulario Streamlit
#
# Esta actividad prepara la app de S5 y la evolución de S6. No implementes el modelo. Completa las decisiones y conserva la evidencia.

# %%
from pathlib import Path
import json

repo_root = next(parent for parent in (Path.cwd(), *Path.cwd().parents)
                 if (parent / 'semana4/assets/04-model-packaging/manifest_example.json').is_file())
manifest_path = repo_root / 'semana4/assets/04-model-packaging/manifest_example.json'
manifest = json.loads(manifest_path.read_text(encoding='utf-8'))
print(manifest['feature_names'])
print(manifest['output_labels'])

# %% [markdown]
# ## 1. Tabla del formulario
#
# Completa una fila por feature. Usa los nombres del manifiesto, una etiqueta legible, `number_input`, tipo numérico, rango del contrato y valor inicial seguro.
#
# | Nombre S4 | Label | Widget | Tipo | Min | Max | Inicial |
# | --- | --- | --- | --- | ---: | ---: | ---: |
# | `fixed_acidity` | TODO | TODO | TODO | TODO | TODO | TODO |
# | … | TODO | TODO | TODO | TODO | TODO | TODO |

# %% [markdown]
# ## 2. Momento de envío
#
# Responde:
#
# - ¿Qué evento envía la petición?
# - ¿Qué no debe ocurrir al cambiar un campo?
# - ¿Qué datos viajan al gateway y cuáles son solo de presentación?

# %% [markdown]
# ## 3. Resultado y límites de S5
#
# Define el contenido mínimo de una pantalla de éxito y un mensaje de error básico. Después anota dos problemas que no resolverás todavía y que entregarás como entrada de S6.
#
# - Resultado: TODO
# - Error: TODO
# - Limitación para S6 1: TODO
# - Limitación para S6 2: TODO

# %% [markdown]
# ## Criterios de aceptación
#
# - otra pareja puede implementar el formulario leyendo tu tabla;
# - los once nombres coinciden con S4;
# - la inferencia solo ocurre al enviar;
# - las dos limitaciones de S6 están relacionadas con reruns, estado, caché o errores.
